# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
from PIL import Image
import os
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # Introduction to Tensorflow
#
# For this talk, I wanted to go over the "next step" after completing some of the basic Tensorflow tutorials found on the website. Specifically this code base will cover how to read data from different data sources with random transformations, implementing a inception network, running transfer learning, and vizualizing the learned feautres. The slides for the presentation can be found in this repository.

# %% [markdown]
# ## Importing the data
#
# Lets start by reading in the data and saving it in the form of a .tfrecords binary file and as a directory.

# %%
from dataset_creation import create_data
create_data()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Test Bincount: [ 963 1111 1019 1024  967  890 1048 1057  941  980]
# Valid Bincount: [491 574 510 461 496 468 490 573 475 462]
# Train Bincount: [5449 6192 5461 5656 5361 4955 5338 5663 5409 5516]
# Writing /home/pspitler3/MNIST/data/train.tfrecords
# (55000, 28, 28)
# (55000,)
# Writing /home/pspitler3/MNIST/data/valid.tfrecords
# (5000, 28, 28)
# (5000,)
# Writing /home/pspitler3/MNIST/data/test.tfrecords
# (10000, 28, 28)
# (10000,)
# Test Bincount: [1028 1091 1042 1028  982  934  955 1002  967  971]
# Valid Bincount: [493 593 487 524 524 454 496 518 442 469]
# Train Bincount: [5382 6193 5461 5589 5318 4925 5425 5773 5416 5518]

# %% [markdown]
# ## Run the models
#
# Once the data is imported and saved, we can run the basic model, the inception model, and transfer the weights from the basic model to create a fully convolutional version of the basic model. The code will run the basic model then run it again with an updated learning rate. This illustrates a save/restore of the model.
#
# For the semantic segmentation model it is of special note that the accuracy initializes very high. This is becuase we already learned the features in the basic_model code!

# %%
from models.base_convnet import basic_model

basic_model(lr=0.003, num_epochs=10)
basic_model(lr=0.001, num_epochs=2)
# Out:
# Model Initialized
# Model Initialized
# ------------------------------------------
# Examples/sec:  847.178397507
# Sec/batch:  0.118038892746
# Current epoch:  0.0
# Current learning rate:  0.003
# Minibatch loss at step 0 : 13.9045
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  10.92
# ------------------------------------------
# Examples/sec:  3971.57791076
# Sec/batch:  0.0251789093018
# Current epoch:  0.5
# Current learning rate:  0.003
# Minibatch loss at step 275 : 1.92803
# ------------------------------------------
# Examples/sec:  3932.84824844
# Sec/batch:  0.025426864624
# Current epoch:  1.0
# Current learning rate:  0.003
# Minibatch loss at step 550 : 1.19198
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  85.34
# ------------------------------------------
# Examples/sec:  3879.26859722
# Sec/batch:  0.025778055191
# Current epoch:  1.5
# Current learning rate:  0.003
# Minibatch loss at step 825 : 0.700646
# ------------------------------------------
# Examples/sec:  4154.70961735
# Sec/batch:  0.024069070816
# Current epoch:  2.0
# Current learning rate:  0.003
# Minibatch loss at step 1100 : 0.516059
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  92.68
# ------------------------------------------
# Examples/sec:  3854.45656469
# Sec/batch:  0.0259439945221
# Current epoch:  2.5
# Current learning rate:  0.003
# Minibatch loss at step 1375 : 0.530323
# ------------------------------------------
# Examples/sec:  4210.51448075
# Sec/batch:  0.0237500667572
# Current epoch:  3.0
# Current learning rate:  0.003
# Minibatch loss at step 1650 : 0.490035
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  94.64
# ------------------------------------------
# Examples/sec:  4336.31842853
# Sec/batch:  0.0230610370636
# Current epoch:  3.5
# Current learning rate:  0.003
# Minibatch loss at step 1925 : 0.223217
# ------------------------------------------
# Examples/sec:  3663.40355658
# Sec/batch:  0.0272970199585
# Current epoch:  4.0
# Current learning rate:  0.003
# Minibatch loss at step 2200 : 0.35719
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  95.64
# ------------------------------------------
# Examples/sec:  4251.35721381
# Sec/batch:  0.023521900177
# Current epoch:  4.5
# Current learning rate:  0.003
# Minibatch loss at step 2475 : 0.374059
# ------------------------------------------
# Examples/sec:  4134.27433663
# Sec/batch:  0.024188041687
# Current epoch:  5.0
# Current learning rate:  0.003
# Minibatch loss at step 2750 : 0.175581
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  96.22
# ------------------------------------------
# Examples/sec:  4362.06918069
# Sec/batch:  0.0229249000549
# Current epoch:  5.5
# Current learning rate:  0.003
# Minibatch loss at step 3025 : 0.303201
# ------------------------------------------
# Examples/sec:  4119.45352937
# Sec/batch:  0.0242750644684
# Current epoch:  6.0
# Current learning rate:  0.003
# Minibatch loss at step 3300 : 0.210194
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  96.66
# ------------------------------------------
# Examples/sec:  4238.72584688
# Sec/batch:  0.0235919952393
# Current epoch:  6.5
# Current learning rate:  0.003
# Minibatch loss at step 3575 : 0.231384
# ------------------------------------------
# Examples/sec:  4242.67044305
# Sec/batch:  0.02357006073
# Current epoch:  7.0
# Current learning rate:  0.003
# Minibatch loss at step 3850 : 0.122123
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  96.86
# ------------------------------------------
# Examples/sec:  4095.52005624
# Sec/batch:  0.0244169235229
# Current epoch:  7.5
# Current learning rate:  0.003
# Minibatch loss at step 4125 : 0.0948449
# ------------------------------------------
# Examples/sec:  4278.24313021
# Sec/batch:  0.023374080658
# Current epoch:  8.0
# Current learning rate:  0.003
# Minibatch loss at step 4400 : 0.137247
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.22
# ------------------------------------------
# Examples/sec:  4315.17196679
# Sec/batch:  0.0231740474701
# Current epoch:  8.5
# Current learning rate:  0.003
# Minibatch loss at step 4675 : 0.147509
# ------------------------------------------
# Examples/sec:  4058.58492027
# Sec/batch:  0.0246391296387
# Current epoch:  9.0
# Current learning rate:  0.003
# Minibatch loss at step 4950 : 0.158239
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.32
# ------------------------------------------
# Examples/sec:  4242.49878621
# Sec/batch:  0.0235710144043
# Current epoch:  9.5
# Current learning rate:  0.003
# Minibatch loss at step 5225 : 0.245089
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.48
# ====================================
# Test accuracy:  97.08
# Model Restored
# Model Restored
# ------------------------------------------
# Examples/sec:  539.982594097
# Sec/batch:  0.18519115448
# Current epoch:  0.0
# Current learning rate:  0.001
# Minibatch loss at step 0 : 0.173817
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.46
# ------------------------------------------
# Examples/sec:  4199.04892529
# Sec/batch:  0.0238149166107
# Current epoch:  0.5
# Current learning rate:  0.001
# Minibatch loss at step 275 : 0.148098
# ------------------------------------------
# Examples/sec:  4009.62086305
# Sec/batch:  0.0249400138855
# Current epoch:  1.0
# Current learning rate:  0.001
# Minibatch loss at step 550 : 0.0961432
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.58
# ------------------------------------------
# Examples/sec:  3957.74932297
# Sec/batch:  0.0252668857574
# Current epoch:  1.5
# Current learning rate:  0.001
# Minibatch loss at step 825 : 0.154891
# Model saved in file:  ./base/base.ckpt
# Validation accuracy:  97.6
# ====================================
# Test accuracy:  97.39

# %%
from models.inception_model import inception_model

inception_model(lr=0.0003, num_epochs=10)
inception_model(lr=0.0001, num_epochs=2)
# Out:
# Model Initialized
# ------------------------------------------
# Examples/sec:  489.780513894
# Sec/batch:  0.204173088074
# Current epoch:  0.0
# Current learning rate:  0.0003
# Minibatch loss at step 0 : 4.4085
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  17.78
# ------------------------------------------
# Examples/sec:  2939.43135867
# Sec/batch:  0.0340201854706
# Current epoch:  0.5
# Current learning rate:  0.0003
# Minibatch loss at step 275 : 0.312904
# ------------------------------------------
# Examples/sec:  3111.17836426
# Sec/batch:  0.032142162323
# Current epoch:  1.0
# Current learning rate:  0.0003
# Minibatch loss at step 550 : 0.131214
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  96.96
# ------------------------------------------
# Examples/sec:  3007.14377895
# Sec/batch:  0.0332541465759
# Current epoch:  1.5
# Current learning rate:  0.0003
# Minibatch loss at step 825 : 0.0478257
# ------------------------------------------
# Examples/sec:  3247.59699886
# Sec/batch:  0.0307919979095
# Current epoch:  2.0
# Current learning rate:  0.0003
# Minibatch loss at step 1100 : 0.147177
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  98.1
# ------------------------------------------
# Examples/sec:  3141.96549632
# Sec/batch:  0.03182721138
# Current epoch:  2.5
# Current learning rate:  0.0003
# Minibatch loss at step 1375 : 0.0201052
# ------------------------------------------
# Examples/sec:  3179.5504681
# Sec/batch:  0.0314509868622
# Current epoch:  3.0
# Current learning rate:  0.0003
# Minibatch loss at step 1650 : 0.0825473
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  98.7
# ------------------------------------------
# Examples/sec:  3106.56968907
# Sec/batch:  0.0321898460388
# Current epoch:  3.5
# Current learning rate:  0.0003
# Minibatch loss at step 1925 : 0.0146425
# ------------------------------------------
# Examples/sec:  3179.33355568
# Sec/batch:  0.0314531326294
# Current epoch:  4.0
# Current learning rate:  0.0003
# Minibatch loss at step 2200 : 0.0294375
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  98.9
# ------------------------------------------
# Examples/sec:  2556.30222396
# Sec/batch:  0.0391190052032
# Current epoch:  4.5
# Current learning rate:  0.0003
# Minibatch loss at step 2475 : 0.0240022
# ------------------------------------------
# Examples/sec:  3008.35162313
# Sec/batch:  0.0332407951355
# Current epoch:  5.0
# Current learning rate:  0.0003
# Minibatch loss at step 2750 : 0.0430316
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  98.98
# ------------------------------------------
# Examples/sec:  3037.10590723
# Sec/batch:  0.0329260826111
# Current epoch:  5.5
# Current learning rate:  0.0003
# Minibatch loss at step 3025 : 0.00810635
# ------------------------------------------
# Examples/sec:  2904.60242933
# Sec/batch:  0.0344281196594
# Current epoch:  6.0
# Current learning rate:  0.0003
# Minibatch loss at step 3300 : 0.0107348
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.08
# ------------------------------------------
# Examples/sec:  3095.01616021
# Sec/batch:  0.0323100090027
# Current epoch:  6.5
# Current learning rate:  0.0003
# Minibatch loss at step 3575 : 0.00545633
# ------------------------------------------
# Examples/sec:  3246.84280196
# Sec/batch:  0.0307991504669
# Current epoch:  7.0
# Current learning rate:  0.0003
# Minibatch loss at step 3850 : 0.022713
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.16
# ------------------------------------------
# Examples/sec:  3019.50513653
# Sec/batch:  0.0331180095673
# Current epoch:  7.5
# Current learning rate:  0.0003
# Minibatch loss at step 4125 : 0.0102983
# ------------------------------------------
# Examples/sec:  3058.65571834
# Sec/batch:  0.0326941013336
# Current epoch:  8.0
# Current learning rate:  0.0003
# Minibatch loss at step 4400 : 0.0284631
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.24
# ------------------------------------------
# Examples/sec:  3029.49389306
# Sec/batch:  0.033008813858
# Current epoch:  8.5
# Current learning rate:  0.0003
# Minibatch loss at step 4675 : 0.0025966
# ------------------------------------------
# Examples/sec:  3151.57417009
# Sec/batch:  0.0317301750183
# Current epoch:  9.0
# Current learning rate:  0.0003
# Minibatch loss at step 4950 : 0.0399361
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.22
# ------------------------------------------
# Examples/sec:  3127.53357344
# Sec/batch:  0.0319740772247
# Current epoch:  9.5
# Current learning rate:  0.0003
# Minibatch loss at step 5225 : 0.000919346
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.32
# ====================================
# Test accuracy:  99.13
# Model Restored
# ------------------------------------------
# Examples/sec:  575.535872332
# Sec/batch:  0.173751115799
# Current epoch:  0.0
# Current learning rate:  0.0001
# Minibatch loss at step 0 : 0.0159279
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.32
# ------------------------------------------
# Examples/sec:  3047.58804595
# Sec/batch:  0.032812833786
# Current epoch:  0.5
# Current learning rate:  0.0001
# Minibatch loss at step 275 : 0.00285901
# ------------------------------------------
# Examples/sec:  3071.15273374
# Sec/batch:  0.0325610637665
# Current epoch:  1.0
# Current learning rate:  0.0001
# Minibatch loss at step 550 : 0.0108932
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.34
# ------------------------------------------
# Examples/sec:  3036.84202905
# Sec/batch:  0.032928943634
# Current epoch:  1.5
# Current learning rate:  0.0001
# Minibatch loss at step 825 : 0.00667793
# Model saved in file:  ./incept/incept.ckpt
# Validation accuracy:  99.34
# ====================================
# Test accuracy:  99.26

# %%
from models.semantic_segmentation import semantic_segmentation

semantic_segmentation(lr=0.002, num_epochs=10)
# Out:
# Model Initialized
# Semantic Segmentation Variables Restored
# ------------------------------------------
# Examples/sec:  908.942049934
# Sec/batch:  0.110018014908
# Current epoch:  0.0
# Current learning rate:  0.002
# Minibatch loss at step 0 : 5.43553
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  12.36
# ------------------------------------------
# Examples/sec:  2944.46636293
# Sec/batch:  0.0339620113373
# Current epoch:  0.5
# Current learning rate:  0.002
# Minibatch loss at step 275 : 1.90813
# ------------------------------------------
# Examples/sec:  3530.6778006
# Sec/batch:  0.0283231735229
# Current epoch:  1.0
# Current learning rate:  0.002
# Minibatch loss at step 550 : 1.49584
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  89.2
# ------------------------------------------
# Examples/sec:  3490.6282509
# Sec/batch:  0.0286481380463
# Current epoch:  1.5
# Current learning rate:  0.002
# Minibatch loss at step 825 : 1.04602
# ------------------------------------------
# Examples/sec:  3706.59078457
# Sec/batch:  0.026978969574
# Current epoch:  2.0
# Current learning rate:  0.002
# Minibatch loss at step 1100 : 0.631178
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  93.54
# ------------------------------------------
# Examples/sec:  3547.61014641
# Sec/batch:  0.0281879901886
# Current epoch:  2.5
# Current learning rate:  0.002
# Minibatch loss at step 1375 : 0.633137
# ------------------------------------------
# Examples/sec:  3535.4394956
# Sec/batch:  0.0282850265503
# Current epoch:  3.0
# Current learning rate:  0.002
# Minibatch loss at step 1650 : 0.666315
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  94.54
# ------------------------------------------
# Examples/sec:  3548.12032619
# Sec/batch:  0.0281839370728
# Current epoch:  3.5
# Current learning rate:  0.002
# Minibatch loss at step 1925 : 0.547582
# ------------------------------------------
# Examples/sec:  2189.13964801
# Sec/batch:  0.0456800460815
# Current epoch:  4.0
# Current learning rate:  0.002
# Minibatch loss at step 2200 : 0.414674
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  95.14
# ------------------------------------------
# Examples/sec:  3425.82331417
# Sec/batch:  0.0291900634766
# Current epoch:  4.5
# Current learning rate:  0.002
# Minibatch loss at step 2475 : 0.471381
# ------------------------------------------
# Examples/sec:  3444.44772933
# Sec/batch:  0.0290322303772
# Current epoch:  5.0
# Current learning rate:  0.002
# Minibatch loss at step 2750 : 0.458165
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  95.4
# ------------------------------------------
# Examples/sec:  3285.14117877
# Sec/batch:  0.0304400920868
# Current epoch:  5.5
# Current learning rate:  0.002
# Minibatch loss at step 3025 : 0.433678
# ------------------------------------------
# Examples/sec:  3459.36244794
# Sec/batch:  0.0289070606232
# Current epoch:  6.0
# Current learning rate:  0.002
# Minibatch loss at step 3300 : 0.281844
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  95.72
# ------------------------------------------
# Examples/sec:  3251.17162369
# Sec/batch:  0.0307581424713
# Current epoch:  6.5
# Current learning rate:  0.002
# Minibatch loss at step 3575 : 0.368724
# ------------------------------------------
# Examples/sec:  3443.42971611
# Sec/batch:  0.029040813446
# Current epoch:  7.0
# Current learning rate:  0.002
# Minibatch loss at step 3850 : 0.428851
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  95.98
# ------------------------------------------
# Examples/sec:  3343.24703482
# Sec/batch:  0.0299110412598
# Current epoch:  7.5
# Current learning rate:  0.002
# Minibatch loss at step 4125 : 0.409361
# ------------------------------------------
# Examples/sec:  3413.08335164
# Sec/batch:  0.0292990207672
# Current epoch:  8.0
# Current learning rate:  0.002
# Minibatch loss at step 4400 : 0.34934
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  96.28
# ------------------------------------------
# Examples/sec:  3545.45101056
# Sec/batch:  0.0282051563263
# Current epoch:  8.5
# Current learning rate:  0.002
# Minibatch loss at step 4675 : 0.189854
# ------------------------------------------
# Examples/sec:  3114.96769402
# Sec/batch:  0.032103061676
# Current epoch:  9.0
# Current learning rate:  0.002
# Minibatch loss at step 4950 : 0.303069
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  96.54
# ------------------------------------------
# Examples/sec:  3471.61740484
# Sec/batch:  0.0288050174713
# Current epoch:  9.5
# Current learning rate:  0.002
# Minibatch loss at step 5225 : 0.278891
# Model saved in file:  ./sem_seg/sem_seg.ckpt
# Validation accuracy:  96.4
# ====================================
# Test accuracy:  96.73

# %% [markdown]
# ## Visualizing the Activations
#
# This code base also illustrates the activation layers of a trained network.

# %%
from visualize_activations import visualize_activations

visualize_activations()
# Out:
# img_0.png
# img_9.png
# img_2.png
# img_4.png
# img_6.png
# img_7.png
# img_5.png
# img_8.png
# img_3.png
# img_1.png

# %% [markdown]
# ## Visualizing the Trained Network through Semantic Segmentation
#
# This piece of code throws an image through the network with varying input sizes and and up-samples and combines the predictions. This gives us a heatmap representation of the features that were learned and which ones are robust and specific.

# %%
from plot_semantic_segmentation import create_ss_plots

create_ss_plots()
# Out:
# (80, 192)
# [1, 8, 22, 10]
# 80
# (82, 196)
# [1, 9, 23, 10]
# 82
# (84, 201)
# [1, 9, 24, 10]
# 84
# (86, 206)
# [1, 9, 24, 10]
# 86
# (88, 211)
# [1, 9, 25, 10]
# 88
# (90, 216)
# [1, 10, 25, 10]
# 90
# (92, 220)
# [1, 10, 26, 10]
# 92
# (94, 225)
# [1, 10, 27, 10]
# 94
# (96, 230)
# [1, 10, 27, 10]
# 96
# (98, 235)
# [1, 11, 28, 10]
# 98
# (100, 240)
# [1, 11, 28, 10]
# 100
# (102, 244)
# [1, 11, 29, 10]
# 102
# (104, 249)
# [1, 11, 30, 10]
# 104
# (106, 254)
# [1, 12, 30, 10]
# 106
# (108, 259)
# [1, 12, 31, 10]
# 108
# (110, 264)
# [1, 12, 31, 10]
# 110
# (112, 268)
# [1, 12, 32, 10]
# 112
# (114, 273)
# [1, 13, 33, 10]
# 114
# (116, 278)
# [1, 13, 33, 10]
# 116
# (118, 283)
# [1, 13, 34, 10]
# 118
# (120, 288)
# [1, 13, 34, 10]
# 120
